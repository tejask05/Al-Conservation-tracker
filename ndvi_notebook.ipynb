# %%
import os

print(os.listdir("data"))

# %%
# !pip install rasterio matplotlib numpy

# %%
from utils import load_band, compute_ndvi, plot_ndvi

# Load RED and NIR bands
red = load_band("data/B04.tif")
nir = load_band("data/B08.tif")

# Compute NDVI
ndvi = compute_ndvi(nir, red)

# Plot and save
plot_ndvi(ndvi, "data/output_ndvi.png")
